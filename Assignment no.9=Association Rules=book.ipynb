# %%
pip install mlxtend

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
books = pd.read_csv("C:/Users/SONY/Downloads/book (1).csv")

# %% [markdown]
# # pre-processing

# %% [markdown]
# As the data is not in transaction formation we are using transaction Encoder

# %%
books.head()

# %% [markdown]
# # Apriori Algorithm

# %%
frequent_itemsets = apriori(books, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
# C:\Users\SONY\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                       itemsets
# 0    0.4230                     (ChildBks)
# 1    0.2475                     (YouthBks)
# 2    0.4310                      (CookBks)
# 3    0.2820                     (DoItYBks)
# 4    0.2145                       (RefBks)
# 5    0.2410                       (ArtBks)
# 6    0.2760                      (GeogBks)
# 7    0.1135                     (ItalCook)
# 8    0.1085                     (Florence)
# 9    0.1650           (YouthBks, ChildBks)
# 10   0.2560            (CookBks, ChildBks)
# 11   0.1840           (ChildBks, DoItYBks)
# 12   0.1515             (RefBks, ChildBks)
# 13   0.1625             (ArtBks, ChildBks)
# ...

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.7)
rules
# Out:
#           antecedents         consequents  antecedent support  \
# 0          (YouthBks)          (ChildBks)              0.2475
# 1          (ChildBks)          (YouthBks)              0.4230
# 2           (CookBks)          (ChildBks)              0.4310
# 3          (ChildBks)           (CookBks)              0.4230
# 4          (ChildBks)          (DoItYBks)              0.4230
# ..                ...                 ...                 ...
# 95  (CookBks, ArtBks)           (GeogBks)              0.1670
# 96  (ArtBks, GeogBks)           (CookBks)              0.1275
# 97          (CookBks)   (ArtBks, GeogBks)              0.4310
# 98          (GeogBks)   (CookBks, ArtBks)              0.2760
# 99           (ArtBks)  (CookBks, GeogBks)              0.2410
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0               0.4230   0.1650    0.666667  1.576044  0.060308    1.731000
# ...

# %%
#### An leverage value of 0 indicates independence.Range will be [-1,1]
#high conviction value means that the consequent is highly depending on the antecedent and range

# %%
rules.sort_values('lift', ascending = False)[0:20]
# Out:
#             antecedents          consequents  antecedent support  \
# 28            (CookBks)           (ItalCook)              0.4310
# 29           (ItalCook)            (CookBks)              0.1135
# 77   (ArtBks, ChildBks)            (GeogBks)              0.1625
# 80            (GeogBks)   (ArtBks, ChildBks)              0.2760
# 86             (ArtBks)  (CookBks, DoItYBks)              0.2410
# 83  (CookBks, DoItYBks)             (ArtBks)              0.1875
# 98            (GeogBks)    (CookBks, ArtBks)              0.2760
# 95    (CookBks, ArtBks)            (GeogBks)              0.1670
# 99             (ArtBks)   (CookBks, GeogBks)              0.2410
# 94   (CookBks, GeogBks)             (ArtBks)              0.1925
# 53  (CookBks, ChildBks)             (RefBks)              0.2560
# 56             (RefBks)  (CookBks, ChildBks)              0.2145
# 79             (ArtBks)  (GeogBks, ChildBks)              0.2410
# ...

# %%
x = rules.support
y = rules.confidence

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.xlabel('support')
plt.ylabel('confidence')
# Out:
# Text(0, 0.5, 'confidence')

# %%
plt.hist(x)
# Out:
# (array([40., 24.,  8., 14.,  4.,  6.,  2.,  0.,  0.,  2.]),
#  array([0.101 , 0.1165, 0.132 , 0.1475, 0.163 , 0.1785, 0.194 , 0.2095,
#         0.225 , 0.2405, 0.256 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y)
# Out:
# (array([12., 16., 16., 17., 11.,  8.,  6., 13.,  0.,  1.]),
#  array([0.23549884, 0.31194896, 0.38839907, 0.46484919, 0.5412993 ,
#         0.61774942, 0.69419954, 0.77064965, 0.84709977, 0.92354988,
#         1.        ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x238a97f94c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x238a97f9b20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x238a97f9070>],
#  'medians': [<matplotlib.lines.Line2D at 0x238a9807280>],
#  'fliers': [<matplotlib.lines.Line2D at 0x238a9807610>],
#  'means': []}

# %%
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x238a9861f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x238a9872670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x238a9861b80>],
#  'medians': [<matplotlib.lines.Line2D at 0x238a9872d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x238a987f160>],
#  'means': []}

# %%
rules[rules.lift>1]
# Out:
#           antecedents         consequents  antecedent support  \
# 0          (YouthBks)          (ChildBks)              0.2475
# 1          (ChildBks)          (YouthBks)              0.4230
# 2           (CookBks)          (ChildBks)              0.4310
# 3          (ChildBks)           (CookBks)              0.4230
# 4          (ChildBks)          (DoItYBks)              0.4230
# ..                ...                 ...                 ...
# 95  (CookBks, ArtBks)           (GeogBks)              0.1670
# 96  (ArtBks, GeogBks)           (CookBks)              0.1275
# 97          (CookBks)   (ArtBks, GeogBks)              0.4310
# 98          (GeogBks)   (CookBks, ArtBks)              0.2760
# 99           (ArtBks)  (CookBks, GeogBks)              0.2410
#
#     consequent support  support  confidence      lift  leverage  conviction
# 0               0.4230   0.1650    0.666667  1.576044  0.060308    1.731000
# ...

# %%
fitemsets = apriori(books, min_support=0.2,use_colnames=True)
# Out:
# C:\Users\SONY\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
fitemsets
# Out:
#    support             itemsets
# 0   0.4230           (ChildBks)
# 1   0.2475           (YouthBks)
# 2   0.4310            (CookBks)
# 3   0.2820           (DoItYBks)
# 4   0.2145             (RefBks)
# 5   0.2410             (ArtBks)
# 6   0.2760            (GeogBks)
# 7   0.2560  (CookBks, ChildBks)

# %%
rules = association_rules(fitemsets, metric="lift", min_threshold=0.7)
rules
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0   (CookBks)  (ChildBks)               0.431               0.423    0.256
# 1  (ChildBks)   (CookBks)               0.423               0.431    0.256
#
#    confidence      lift  leverage  conviction
# 0    0.593968  1.404179  0.073687    1.421069
# 1    0.605201  1.404179  0.073687    1.441240

# %%
fitemset = apriori(books, min_support=0.15,use_colnames=True)
# Out:
# C:\Users\SONY\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
fitemset
# Out:
#     support              itemsets
# 0    0.4230            (ChildBks)
# 1    0.2475            (YouthBks)
# 2    0.4310             (CookBks)
# 3    0.2820            (DoItYBks)
# 4    0.2145              (RefBks)
# 5    0.2410              (ArtBks)
# 6    0.2760             (GeogBks)
# 7    0.1650  (YouthBks, ChildBks)
# 8    0.2560   (CookBks, ChildBks)
# 9    0.1840  (ChildBks, DoItYBks)
# 10   0.1515    (RefBks, ChildBks)
# 11   0.1625    (ArtBks, ChildBks)
# 12   0.1950   (GeogBks, ChildBks)
# 13   0.1620   (CookBks, YouthBks)
# 14   0.1875   (CookBks, DoItYBks)
# 15   0.1525     (CookBks, RefBks)
# 16   0.1670     (CookBks, ArtBks)
# 17   0.1925    (CookBks, GeogBks)

# %%
rules = association_rules(fitemset, metric="lift", min_threshold=0.7)
rules
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0   (YouthBks)  (ChildBks)              0.2475              0.4230   0.1650
# 1   (ChildBks)  (YouthBks)              0.4230              0.2475   0.1650
# 2    (CookBks)  (ChildBks)              0.4310              0.4230   0.2560
# 3   (ChildBks)   (CookBks)              0.4230              0.4310   0.2560
# 4   (ChildBks)  (DoItYBks)              0.4230              0.2820   0.1840
# 5   (DoItYBks)  (ChildBks)              0.2820              0.4230   0.1840
# 6     (RefBks)  (ChildBks)              0.2145              0.4230   0.1515
# 7   (ChildBks)    (RefBks)              0.4230              0.2145   0.1515
# 8     (ArtBks)  (ChildBks)              0.2410              0.4230   0.1625
# 9   (ChildBks)    (ArtBks)              0.4230              0.2410   0.1625
# 10   (GeogBks)  (ChildBks)              0.2760              0.4230   0.1950
# ...

# %%
rules.sort_values('lift',ascending = False)[0:10]
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 11  (ChildBks)   (GeogBks)              0.4230              0.2760   0.1950
# 10   (GeogBks)  (ChildBks)              0.2760              0.4230   0.1950
# 7   (ChildBks)    (RefBks)              0.4230              0.2145   0.1515
# 6     (RefBks)  (ChildBks)              0.2145              0.4230   0.1515
# 17    (RefBks)   (CookBks)              0.2145              0.4310   0.1525
# 16   (CookBks)    (RefBks)              0.4310              0.2145   0.1525
# 20   (CookBks)   (GeogBks)              0.4310              0.2760   0.1925
# 21   (GeogBks)   (CookBks)              0.2760              0.4310   0.1925
# 18   (CookBks)    (ArtBks)              0.4310              0.2410   0.1670
# 19    (ArtBks)   (CookBks)              0.2410              0.4310   0.1670
#
#     confidence      lift  leverage  conviction
# 11    0.460993  1.670264  0.078252    1.343211
# ...

# %%
x = rules.support
y = rules.confidence

# %%
plt.scatter(x,y)
plt.xlabel('support')
plt.ylabel('confidence')
# Out:
# Text(0, 0.5, 'confidence')

# %%
rules.drop_duplicates(subset=['support'])
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0   (YouthBks)  (ChildBks)              0.2475              0.4230   0.1650
# 2    (CookBks)  (ChildBks)              0.4310              0.4230   0.2560
# 4   (ChildBks)  (DoItYBks)              0.4230              0.2820   0.1840
# 6     (RefBks)  (ChildBks)              0.2145              0.4230   0.1515
# 8     (ArtBks)  (ChildBks)              0.2410              0.4230   0.1625
# 10   (GeogBks)  (ChildBks)              0.2760              0.4230   0.1950
# 12   (CookBks)  (YouthBks)              0.4310              0.2475   0.1620
# 14   (CookBks)  (DoItYBks)              0.4310              0.2820   0.1875
# 16   (CookBks)    (RefBks)              0.4310              0.2145   0.1525
# 18   (CookBks)    (ArtBks)              0.4310              0.2410   0.1670
# 20   (CookBks)   (GeogBks)              0.4310              0.2760   0.1925
#
#     confidence      lift  leverage  conviction
# ...
